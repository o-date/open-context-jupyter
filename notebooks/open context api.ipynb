# %%
# Make the Requests module available
import requests

# %%
# Create a variable called 'api_search_url' and give it a value
api_search_url = 'https://opencontext.org/search/.json?'

# %%
# This creates a dictionary called 'params' and sets values for the API's mandatory parameters
params = {
    'q': 'roman' # Search for this keyword -- feel free to change!
    
}

# %%
# Let's view the updated dictionary
params
# Out:
# {'q': 'roman'}

# %%
# This sends our request to the Trove API and stores the result in a variable called 'response'
response = requests.get(api_search_url, params=params)

# This shows us the url that's sent to the API
print('Here\'s the formatted url that gets sent to the Open Context API:\n{}\n'.format(response.url)) 

# This checks the status code of the response to make sure there were no errors
if response.status_code == requests.codes.ok:
    print('All ok')
elif response.status_code == 403:
    print('There was an authentication error. Did you paste your API above?')
else:
    print('There was a problem. Error code: {}'.format(response.status_code))
    print('Try running this cell again.')
# Out:
# Here's the formatted url that gets sent to the Open Context API:
# https://opencontext.org/search/.json?q=roman
#
# All ok

# %%
# Get the API's JSON results and make them available as a Python variable called 'data'
data = response.json()

# %%
# Let's prettify the raw JSON data and then display it.

# We're using the Pygments library to add some colour to the output, so we need to import it
import json
from pygments import highlight, lexers, formatters

# This uses Python's JSON module to output the results as nicely indented text
formatted_data = json.dumps(data, indent=2)

# This colours the text
highlighted_data = highlight(formatted_data, lexers.JsonLexer(), formatters.TerminalFormatter())

# And now display the results
print(highlighted_data)
# Out:
# {
#   "oc-api:geotile-scope": null,
#   "features": [
#     {
#       "count": 2,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-032021",
#         "coordinates": [
#           [
#             [
#               -84.375,
#               27.059125784374068
#             ],
#             [
#               -78.75000000000001,
#               27.059125784374068
#             ],
#             [
#               -78.75000000000001,
#               31.952162238024975
#             ],
#             [
#               -84.375,
#               31.952162238024975
#             ],
#             [
#               -84.375,
#               27.059125784374068
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-032021"
#       },
#       "properties": {
#         "count": 2,
#         "label": "Discovery region (1)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=032021",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-032021"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=032021",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=032021"
#     },
#     {
#       "count": 6343,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-122103",
#         "coordinates": [
#           [
#             [
#               28.125,
#               31.952162238024975
#             ],
#             [
#               33.750000000000014,
#               31.952162238024975
#             ],
#             [
#               33.750000000000014,
#               36.5978891330702
#             ],
#             [
#               28.125,
#               36.5978891330702
#             ],
#             [
#               28.125,
#               31.952162238024975
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-122103"
#       },
#       "properties": {
#         "count": 6343,
#         "label": "Discovery region (2)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=122103",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-122103"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=122103",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=122103"
#     },
#     {
#       "count": 181,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-122121",
#         "coordinates": [
#           [
#             [
#               28.125,
#               27.059125784374068
#             ],
#             [
#               33.750000000000014,
#               27.059125784374068
#             ],
#             [
#               33.750000000000014,
#               31.952162238024975
#             ],
#             [
#               28.125,
#               31.952162238024975
#             ],
#             [
#               28.125,
#               27.059125784374068
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-122121"
#       },
#       "properties": {
#         "count": 181,
#         "label": "Discovery region (3)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=122121",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-122121"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=122121",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=122121"
#     },
#     {
#       "count": 13,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-122112",
#         "coordinates": [
#           [
#             [
#               33.750000000000014,
#               31.952162238024975
#             ],
#             [
#               39.37499999999999,
#               31.952162238024975
#             ],
#             [
#               39.37499999999999,
#               36.5978891330702
#             ],
#             [
#               33.750000000000014,
#               36.5978891330702
#             ],
#             [
#               33.750000000000014,
#               31.952162238024975
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-122112"
#       },
#       "properties": {
#         "count": 13,
#         "label": "Discovery region (4)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=122112",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-122112"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=122112",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=122112"
#     },
#     {
#       "count": 10,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-120211",
#         "coordinates": [
#           [
#             [
#               16.875000000000007,
#               52.482780222078226
#             ],
#             [
#               22.499999999999986,
#               52.482780222078226
#             ],
#             [
#               22.499999999999986,
#               55.7765730186677
#             ],
#             [
#               16.875000000000007,
#               55.7765730186677
#             ],
#             [
#               16.875000000000007,
#               52.482780222078226
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-120211"
#       },
#       "properties": {
#         "count": 10,
#         "label": "Discovery region (5)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=120211",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-120211"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=120211",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=120211"
#     },
#     {
#       "count": 14,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-122110",
#         "coordinates": [
#           [
#             [
#               33.750000000000014,
#               36.5978891330702
#             ],
#             [
#               39.37499999999999,
#               36.5978891330702
#             ],
#             [
#               39.37499999999999,
#               40.979898069620155
#             ],
#             [
#               33.750000000000014,
#               40.979898069620155
#             ],
#             [
#               33.750000000000014,
#               36.5978891330702
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-122110"
#       },
#       "properties": {
#         "count": 14,
#         "label": "Discovery region (6)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=122110",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-122110"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=122110",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=122110"
#     },
#     {
#       "count": 13,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-120221",
#         "coordinates": [
#           [
#             [
#               5.625000000000013,
#               45.089035564831015
#             ],
#             [
#               11.249999999999993,
#               45.089035564831015
#             ],
#             [
#               11.249999999999993,
#               48.922499263758255
#             ],
#             [
#               5.625000000000013,
#               48.922499263758255
#             ],
#             [
#               5.625000000000013,
#               45.089035564831015
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-120221"
#       },
#       "properties": {
#         "count": 13,
#         "label": "Discovery region (7)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=120221",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-120221"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=120221",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=120221"
#     },
#     {
#       "count": 1,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-032000",
#         "coordinates": [
#           [
#             [
#               -90.0,
#               36.5978891330702
#             ],
#             [
#               -84.375,
#               36.5978891330702
#             ],
#             [
#               -84.375,
#               40.979898069620155
#             ],
#             [
#               -90.0,
#               40.979898069620155
#             ],
#             [
#               -90.0,
#               36.5978891330702
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-032000"
#       },
#       "properties": {
#         "count": 1,
#         "label": "Discovery region (8)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=032000",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-032000"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=032000",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=032000"
#     },
#     {
#       "count": 28,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-033111",
#         "coordinates": [
#           [
#             [
#               -5.625000000000013,
#               36.5978891330702
#             ],
#             [
#               0.0,
#               36.5978891330702
#             ],
#             [
#               0.0,
#               40.979898069620155
#             ],
#             [
#               -5.625000000000013,
#               40.979898069620155
#             ],
#             [
#               -5.625000000000013,
#               36.5978891330702
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-033111"
#       },
#       "properties": {
#         "count": 28,
#         "label": "Discovery region (9)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=033111",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-033111"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=033111",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=033111"
#     },
#     {
#       "count": 263,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-120203",
#         "coordinates": [
#           [
#             [
#               5.625000000000013,
#               48.922499263758255
#             ],
#             [
#               11.249999999999993,
#               48.922499263758255
#             ],
#             [
#               11.249999999999993,
#               52.482780222078226
#             ],
#             [
#               5.625000000000013,
#               52.482780222078226
#             ],
#             [
#               5.625000000000013,
#               48.922499263758255
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-120203"
#       },
#       "properties": {
#         "count": 263,
#         "label": "Discovery region (10)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=120203",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-120203"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=120203",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=120203"
#     },
#     {
#       "count": 127,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-120201",
#         "coordinates": [
#           [
#             [
#               5.625000000000013,
#               52.482780222078226
#             ],
#             [
#               11.249999999999993,
#               52.482780222078226
#             ],
#             [
#               11.249999999999993,
#               55.7765730186677
#             ],
#             [
#               5.625000000000013,
#               55.7765730186677
#             ],
#             [
#               5.625000000000013,
#               52.482780222078226
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-120201"
#       },
#       "properties": {
#         "count": 127,
#         "label": "Discovery region (11)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=120201",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-120201"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=120201",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=120201"
#     },
#     {
#       "count": 2981,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-122130",
#         "coordinates": [
#           [
#             [
#               33.750000000000014,
#               27.059125784374068
#             ],
#             [
#               39.37499999999999,
#               27.059125784374068
#             ],
#             [
#               39.37499999999999,
#               31.952162238024975
#             ],
#             [
#               33.750000000000014,
#               31.952162238024975
#             ],
#             [
#               33.750000000000014,
#               27.059125784374068
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-122130"
#       },
#       "properties": {
#         "count": 2981,
#         "label": "Discovery region (12)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=122130",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-122130"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=122130",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=122130"
#     },
#     {
#       "count": 1,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-123020",
#         "coordinates": [
#           [
#             [
#               45.00000000000001,
#               27.059125784374068
#             ],
#             [
#               50.62499999999999,
#               27.059125784374068
#             ],
#             [
#               50.62499999999999,
#               31.952162238024975
#             ],
#             [
#               45.00000000000001,
#               31.952162238024975
#             ],
#             [
#               45.00000000000001,
#               27.059125784374068
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-123020"
#       },
#       "properties": {
#         "count": 1,
#         "label": "Discovery region (13)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=123020",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-123020"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=123020",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=123020"
#     },
#     {
#       "count": 980,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-122100",
#         "coordinates": [
#           [
#             [
#               22.499999999999986,
#               36.5978891330702
#             ],
#             [
#               28.125,
#               36.5978891330702
#             ],
#             [
#               28.125,
#               40.979898069620155
#             ],
#             [
#               22.499999999999986,
#               40.979898069620155
#             ],
#             [
#               22.499999999999986,
#               36.5978891330702
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-122100"
#       },
#       "properties": {
#         "count": 980,
#         "label": "Discovery region (14)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=122100",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-122100"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=122100",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=122100"
#     },
#     {
#       "count": 6,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-021333",
#         "coordinates": [
#           [
#             [
#               -95.625,
#               40.979898069620155
#             ],
#             [
#               -90.0,
#               40.979898069620155
#             ],
#             [
#               -90.0,
#               45.089035564831015
#             ],
#             [
#               -95.625,
#               45.089035564831015
#             ],
#             [
#               -95.625,
#               40.979898069620155
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-021333"
#       },
#       "properties": {
#         "count": 6,
#         "label": "Discovery region (15)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=021333",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-021333"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=021333",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=021333"
#     },
#     {
#       "count": 127,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-122101",
#         "coordinates": [
#           [
#             [
#               28.125,
#               36.5978891330702
#             ],
#             [
#               33.750000000000014,
#               36.5978891330702
#             ],
#             [
#               33.750000000000014,
#               40.979898069620155
#             ],
#             [
#               28.125,
#               40.979898069620155
#             ],
#             [
#               28.125,
#               36.5978891330702
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-122101"
#       },
#       "properties": {
#         "count": 127,
#         "label": "Discovery region (16)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=122101",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-122101"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=122101",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=122101"
#     },
#     {
#       "count": 7,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-122131",
#         "coordinates": [
#           [
#             [
#               39.37499999999999,
#               27.059125784374068
#             ],
#             [
#               45.00000000000001,
#               27.059125784374068
#             ],
#             [
#               45.00000000000001,
#               31.952162238024975
#             ],
#             [
#               39.37499999999999,
#               31.952162238024975
#             ],
#             [
#               39.37499999999999,
#               27.059125784374068
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-122131"
#       },
#       "properties": {
#         "count": 7,
#         "label": "Discovery region (17)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=122131",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-122131"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=122131",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=122131"
#     },
#     {
#       "count": 56,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-120212",
#         "coordinates": [
#           [
#             [
#               11.249999999999993,
#               48.922499263758255
#             ],
#             [
#               16.875000000000007,
#               48.922499263758255
#             ],
#             [
#               16.875000000000007,
#               52.482780222078226
#             ],
#             [
#               11.249999999999993,
#               52.482780222078226
#             ],
#             [
#               11.249999999999993,
#               48.922499263758255
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-120212"
#       },
#       "properties": {
#         "count": 56,
#         "label": "Discovery region (18)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=120212",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-120212"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=120212",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=120212"
#     },
#     {
#       "count": 9604,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-120232",
#         "coordinates": [
#           [
#             [
#               11.249999999999993,
#               40.979898069620155
#             ],
#             [
#               16.875000000000007,
#               40.979898069620155
#             ],
#             [
#               16.875000000000007,
#               45.089035564831015
#             ],
#             [
#               11.249999999999993,
#               45.089035564831015
#             ],
#             [
#               11.249999999999993,
#               40.979898069620155
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-120232"
#       },
#       "properties": {
#         "count": 9604,
#         "label": "Discovery region (19)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=120232",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-120232"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=120232",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=120232"
#     },
#     {
#       "count": 1,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-023301",
#         "coordinates": [
#           [
#             [
#               -106.875,
#               16.636191878397664
#             ],
#             [
#               -101.25,
#               16.636191878397664
#             ],
#             [
#               -101.25,
#               21.943045533438166
#             ],
#             [
#               -106.875,
#               21.943045533438166
#             ],
#             [
#               -106.875,
#               16.636191878397664
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-023301"
#       },
#       "properties": {
#         "count": 1,
#         "label": "Discovery region (20)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=023301",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-023301"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=023301",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=023301"
#     },
#     {
#       "count": 15,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-122111",
#         "coordinates": [
#           [
#             [
#               39.37499999999999,
#               36.5978891330702
#             ],
#             [
#               45.00000000000001,
#               36.5978891330702
#             ],
#             [
#               45.00000000000001,
#               40.979898069620155
#             ],
#             [
#               39.37499999999999,
#               40.979898069620155
#             ],
#             [
#               39.37499999999999,
#               36.5978891330702
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-122111"
#       },
#       "properties": {
#         "count": 15,
#         "label": "Discovery region (21)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=122111",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-122111"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=122111",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=122111"
#     },
#     {
#       "count": 3,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-023131",
#         "coordinates": [
#           [
#             [
#               -95.625,
#               27.059125784374068
#             ],
#             [
#               -90.0,
#               27.059125784374068
#             ],
#             [
#               -90.0,
#               31.952162238024975
#             ],
#             [
#               -95.625,
#               31.952162238024975
#             ],
#             [
#               -95.625,
#               27.059125784374068
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-023131"
#       },
#       "properties": {
#         "count": 3,
#         "label": "Discovery region (22)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=023131",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-023131"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=023131",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=023131"
#     },
#     {
#       "count": 1,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-030222",
#         "coordinates": [
#           [
#             [
#               -90.0,
#               40.979898069620155
#             ],
#             [
#               -84.375,
#               40.979898069620155
#             ],
#             [
#               -84.375,
#               45.089035564831015
#             ],
#             [
#               -90.0,
#               45.089035564831015
#             ],
#             [
#               -90.0,
#               40.979898069620155
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-030222"
#       },
#       "properties": {
#         "count": 1,
#         "label": "Discovery region (23)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=030222",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-030222"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=030222",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=030222"
#     },
#     {
#       "count": 29,
#       "category": "oc-api:geo-facet",
#       "geometry": {
#         "type": "Polygon",
#         "id": "#geo-disc-tile-geom-120210",
#         "coordinates": [
#           [
#             [
#               11.249999999999993,
#               52.482780222078226
#             ],
#             [
#               16.875000000000007,
#               52.482780222078226
#             ],
#             [
#               16.875000000000007,
#               55.7765730186677
#             ],
#             [
#               11.249999999999993,
#               55.7765730186677
#             ],
#             [
#               11.249999999999993,
#               52.482780222078226
#             ]
#           ]
#         ]
#       },
#       "when": {
#         "stop": "1950",
#         "start": "-336999",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-120210"
#       },
#       "properties": {
#         "count": 29,
#         "label": "Discovery region (24)",
#         "late bce/ce": 1950,
#         "href": "https://opencontext.org/search/?q=roman&disc-geotile=120210",
#         "early bce/ce": -337000,
#         "feature-type": "discovery region (facet)",
#         "id": "#geo-disc-tile-120210"
#       },
#       "json": "https://opencontext.org/search/.json?q=roman&disc-geotile=120210",
#       "type": "Feature",
#       "id": "https://opencontext.org/search/?q=roman&disc-geotile=120210"
#     },
#     {
#       "category": "oc-api:geo-record",
#       "properties": {
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "updated": "2018-03-23T01:20:16Z",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx Northwest/Feature FNWa2",
#         "published": "2017-12-23T01:03:45Z",
#         "uri": "http://opencontext.org/media/433b76a4-d91e-48ec-9821-70dbaf510957",
#         "item category": "Image",
#         "label": "Drawing d-nw-004",
#         "snippet": " small (modern and <em>Roman</em>) veneer stones immediately west of the N Large Box (\"caison\"). Profile shows the",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/101-drawing-d-nw-004.jpg",
#         "late bce/ce": false,
#         "href": "https://opencontext.org/media/433b76a4-d91e-48ec-9821-70dbaf510957",
#         "early bce/ce": false,
#         "feature-type": "item record",
#         "context href": "https://opencontext.org/subjects/cecae52e-d854-4798-ba27-03edfb538bd0",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "citation uri": false,
#         "id": "#rec-1-of-21565"
#       },
#       "geometry": {
#         "type": "Point",
#         "id": "#geo-rec-geom-1-of-21565",
#         "coordinates": [
#           31.137304256746678,
#           29.975380310025677
#         ]
#       },
#       "rdfs:isDefinedBy": "http://opencontext.org/media/433b76a4-d91e-48ec-9821-70dbaf510957",
#       "label": "Drawing d-nw-004",
#       "type": "Feature",
#       "id": "#record-1-of-21565"
#     },
#     {
#       "category": "oc-api:geo-record",
#       "properties": {
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "updated": "2018-03-23T01:22:16Z",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx Northwest/Feature FNWa2",
#         "published": "2017-12-23T01:03:41Z",
#         "uri": "http://opencontext.org/media/607284d3-0506-4db5-b491-6a567e0544c0",
#         "item category": "Image",
#         "label": "Drawing d-nw-001",
#         "snippet": " \n Description NWa2: Large fine limestone block showing after removal of small (modern and <em>Roman</em>) veneer stones",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/101-drawing-d-nw-001.jpg",
#         "late bce/ce": false,
#         "href": "https://opencontext.org/media/607284d3-0506-4db5-b491-6a567e0544c0",
#         "early bce/ce": false,
#         "feature-type": "item record",
#         "context href": "https://opencontext.org/subjects/cecae52e-d854-4798-ba27-03edfb538bd0",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "citation uri": false,
#         "id": "#rec-2-of-21565"
#       },
#       "geometry": {
#         "type": "Point",
#         "id": "#geo-rec-geom-2-of-21565",
#         "coordinates": [
#           31.137304256746678,
#           29.975380310025677
#         ]
#       },
#       "rdfs:isDefinedBy": "http://opencontext.org/media/607284d3-0506-4db5-b491-6a567e0544c0",
#       "label": "Drawing d-nw-001",
#       "type": "Feature",
#       "id": "#record-2-of-21565"
#     },
#     {
#       "category": "oc-api:geo-record",
#       "properties": {
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "updated": "2018-03-23T01:20:12Z",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14",
#         "published": "2017-12-23T01:02:26Z",
#         "uri": "http://opencontext.org/media/99478565-701f-4329-be42-dce415b9b68a",
#         "item category": "Image",
#         "label": "Drawing d-n-008",
#         "snippet": " R14 was the removal of a small amount of deposits immediately south of the <em>Roman</em> Stairs, between the",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/101-drawing-d-n-008.jpg",
#         "late bce/ce": false,
#         "href": "https://opencontext.org/media/99478565-701f-4329-be42-dce415b9b68a",
#         "early bce/ce": false,
#         "feature-type": "item record",
#         "context href": "https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "citation uri": false,
#         "id": "#rec-3-of-21565"
#       },
#       "geometry": {
#         "type": "Point",
#         "id": "#geo-rec-geom-3-of-21565",
#         "coordinates": [
#           31.137937830616877,
#           29.97526657483614
#         ]
#       },
#       "rdfs:isDefinedBy": "http://opencontext.org/media/99478565-701f-4329-be42-dce415b9b68a",
#       "label": "Drawing d-n-008",
#       "type": "Feature",
#       "id": "#record-3-of-21565"
#     },
#     {
#       "category": "oc-api:geo-record",
#       "properties": {
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "updated": "2018-03-23T01:05:18Z",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14",
#         "published": "2017-12-23T01:01:31Z",
#         "uri": "http://opencontext.org/media/27d3136b-3023-45e4-ae86-901fa8ad8342",
#         "item category": "Image",
#         "label": "Drawing d-e-016",
#         "snippet": " immediately south of the <em>Roman</em> Stairs, between the stairs and the Sound and Light box and a core block of the",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-016.jpg",
#         "late bce/ce": false,
#         "href": "https://opencontext.org/media/27d3136b-3023-45e4-ae86-901fa8ad8342",
#         "early bce/ce": false,
#         "feature-type": "item record",
#         "context href": "https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "citation uri": false,
#         "id": "#rec-4-of-21565"
#       },
#       "geometry": {
#         "type": "Point",
#         "id": "#geo-rec-geom-4-of-21565",
#         "coordinates": [
#           31.137937830616877,
#           29.97526657483614
#         ]
#       },
#       "rdfs:isDefinedBy": "http://opencontext.org/media/27d3136b-3023-45e4-ae86-901fa8ad8342",
#       "label": "Drawing d-e-016",
#       "type": "Feature",
#       "id": "#record-4-of-21565"
#     },
#     {
#       "category": "oc-api:geo-record",
#       "properties": {
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "updated": "2018-03-23T01:05:51Z",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14",
#         "published": "2017-12-23T01:01:31Z",
#         "uri": "http://opencontext.org/media/4f1437de-aef1-4f43-8c0b-47eb8e7fe850",
#         "item category": "Image",
#         "label": "Drawing d-e-017",
#         "snippet": " <em>Roman</em> Stairs, between the stairs and the Sound and Light box and a core block of the west Sphinx Temple",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-017.jpg",
#         "late bce/ce": false,
#         "href": "https://opencontext.org/media/4f1437de-aef1-4f43-8c0b-47eb8e7fe850",
#         "early bce/ce": false,
#         "feature-type": "item record",
#         "context href": "https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "citation uri": false,
#         "id": "#rec-5-of-21565"
#       },
#       "geometry": {
#         "type": "Point",
#         "id": "#geo-rec-geom-5-of-21565",
#         "coordinates": [
#           31.137937830616877,
#           29.97526657483614
#         ]
#       },
#       "rdfs:isDefinedBy": "http://opencontext.org/media/4f1437de-aef1-4f43-8c0b-47eb8e7fe850",
#       "label": "Drawing d-e-017",
#       "type": "Feature",
#       "id": "#record-5-of-21565"
#     },
#     {
#       "category": "oc-api:geo-record",
#       "properties": {
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "updated": "2018-03-23T01:02:11Z",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14",
#         "published": "2017-12-23T01:01:33Z",
#         "uri": "http://opencontext.org/media/846687bc-2e8c-4b44-876c-4873e4278250",
#         "item category": "Image",
#         "label": "Drawing d-e-019",
#         "snippet": " R14 was the removal of a small amount of deposits immediately south of the <em>Roman</em> Stairs, between the",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-019.jpg",
#         "late bce/ce": false,
#         "href": "https://opencontext.org/media/846687bc-2e8c-4b44-876c-4873e4278250",
#         "early bce/ce": false,
#         "feature-type": "item record",
#         "context href": "https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "citation uri": false,
#         "id": "#rec-6-of-21565"
#       },
#       "geometry": {
#         "type": "Point",
#         "id": "#geo-rec-geom-6-of-21565",
#         "coordinates": [
#           31.137937830616877,
#           29.97526657483614
#         ]
#       },
#       "rdfs:isDefinedBy": "http://opencontext.org/media/846687bc-2e8c-4b44-876c-4873e4278250",
#       "label": "Drawing d-e-019",
#       "type": "Feature",
#       "id": "#record-6-of-21565"
#     },
#     {
#       "category": "oc-api:geo-record",
#       "properties": {
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "updated": "2018-03-23T01:22:18Z",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14",
#         "published": "2017-12-23T01:01:35Z",
#         "uri": "http://opencontext.org/media/b9a02c98-e11d-47c7-81c4-db140c1712ed",
#         "item category": "Image",
#         "label": "Drawing d-e-022",
#         "snippet": " of <em>Roman</em> pavement and SE of South Forepaw \n \n Year  \n Resource Type  Drawings  \n Keywords  Depression",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-022.jpg",
#         "late bce/ce": false,
#         "href": "https://opencontext.org/media/b9a02c98-e11d-47c7-81c4-db140c1712ed",
#         "early bce/ce": false,
#         "feature-type": "item record",
#         "context href": "https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "citation uri": false,
#         "id": "#rec-7-of-21565"
#       },
#       "geometry": {
#         "type": "Point",
#         "id": "#geo-rec-geom-7-of-21565",
#         "coordinates": [
#           31.137937830616877,
#           29.97526657483614
#         ]
#       },
#       "rdfs:isDefinedBy": "http://opencontext.org/media/b9a02c98-e11d-47c7-81c4-db140c1712ed",
#       "label": "Drawing d-e-022",
#       "type": "Feature",
#       "id": "#record-7-of-21565"
#     },
#     {
#       "category": "oc-api:geo-record",
#       "properties": {
#         "project label": "The Gabii Project",
#         "updated": "2018-01-31T08:15:43Z",
#         "context label": "Italy/Gabii/Area B/Unit 1162",
#         "published": "2017-06-04T23:27:35Z",
#         "uri": "http://opencontext.org/media/07c8b5d2-dab1-4b21-ae90-ceb0ffe515b0",
#         "item category": "Image",
#         "label": "2771",
#         "snippet": " Priority  Medium  \n File Attachment Filename 2771.pdf \n \n<em>Roman</em> Republican\nhttp://n2t.net/ark:/99152",
#         "thumbnail": "https://opencontext.org/static/oc/images/icons/3d-noun-37529.png",
#         "late bce/ce": -50.0,
#         "href": "https://opencontext.org/media/07c8b5d2-dab1-4b21-ae90-ceb0ffe515b0",
#         "early bce/ce": -500.0,
#         "feature-type": "item record",
#         "context href": "https://opencontext.org/subjects/98014789-c3a6-48c6-9da8-8598d1c026eb",
#         "project href": "https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd",
#         "citation uri": false,
#         "id": "#rec-8-of-21565"
#       },
#       "geometry": {
#         "type": "Point",
#         "id": "#geo-rec-geom-8-of-21565",
#         "coordinates": [
#           12.719540897587173,
#           41.88768286105927
#         ]
#       },
#       "when": {
#         "stop": "-0049",
#         "start": "-0499",
#         "type": "oc-gen:formation-use-life",
#         "id": "#event-rec-when-8-of-21565"
#       },
#       "rdfs:isDefinedBy": "http://opencontext.org/media/07c8b5d2-dab1-4b21-ae90-ceb0ffe515b0",
#       "label": "2771",
#       "type": "Feature",
#       "id": "#record-8-of-21565"
#     },
#     {
#       "category": "oc-api:geo-record",
#       "properties": {
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "updated": "2018-03-23T01:04:19Z",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Roman Pavement/Removal 15",
#         "published": "2017-12-23T01:01:33Z",
#         "uri": "http://opencontext.org/media/254e87ae-8e32-43c9-a13b-71d579213978",
#         "item category": "Image",
#         "label": "Drawing d-e-020",
#         "snippet": "Drawing d-e-020 from Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/<em>Roman</em> Pavement/Removal",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-020.jpg",
#         "late bce/ce": false,
#         "href": "https://opencontext.org/media/254e87ae-8e32-43c9-a13b-71d579213978",
#         "early bce/ce": false,
#         "feature-type": "item record",
#         "context href": "https://opencontext.org/subjects/c89534ea-27ef-4989-9330-188925c983b8",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "citation uri": false,
#         "id": "#rec-9-of-21565"
#       },
#       "geometry": {
#         "type": "Point",
#         "id": "#geo-rec-geom-9-of-21565",
#         "coordinates": [
#           31.13804786067644,
#           29.97526634987221
#         ]
#       },
#       "rdfs:isDefinedBy": "http://opencontext.org/media/254e87ae-8e32-43c9-a13b-71d579213978",
#       "label": "Drawing d-e-020",
#       "type": "Feature",
#       "id": "#record-9-of-21565"
#     },
#     {
#       "category": "oc-api:geo-record",
#       "properties": {
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "updated": "2018-03-23T01:02:54Z",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Roman Pavement/Removal 15",
#         "published": "2017-12-23T01:01:34Z",
#         "uri": "http://opencontext.org/media/14851d29-eb3f-431e-84cc-d1d90fc165eb",
#         "item category": "Image",
#         "label": "Drawing d-e-021",
#         "snippet": "Drawing d-e-021 from Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/<em>Roman</em> Pavement/Removal",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-021.jpg",
#         "late bce/ce": false,
# ...
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/295B5BF4-0F44-4698-80CD-7A39CB6F133D",
#           "label": "Rough Cilicia",
#           "json": "https://opencontext.org/search/.json?q=roman&proj=21-rough-cilicia",
#           "id": "https://opencontext.org/search/?q=roman&proj=21-rough-cilicia"
#         },
#         {
#           "count": 1,
#           "slug": "26-zooarchaeology-of-karain-cave-b",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/731B0670-CE2A-414A-8EF6-9C050A1C60F5",
#           "label": "Zooarchaeology of Karain Cave B",
#           "json": "https://opencontext.org/search/.json?q=roman&proj=26-zooarchaeology-of-karain-cave-b",
#           "id": "https://opencontext.org/search/?q=roman&proj=26-zooarchaeology-of-karain-cave-b"
#         },
#         {
#           "count": 1,
#           "slug": "31-barcin-hoyuk-zooarchaeology",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/74749949-4FD4-4C3E-C830-5AA75703E08E",
#           "label": "Bar\u00e7\u0131n H\u00f6y\u00fck Zooarchaeology",
#           "json": "https://opencontext.org/search/.json?q=roman&proj=31-barcin-hoyuk-zooarchaeology",
#           "id": "https://opencontext.org/search/?q=roman&proj=31-barcin-hoyuk-zooarchaeology"
#         },
#         {
#           "count": 1,
#           "slug": "36-ilipinar-zooarchaeology",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/D297CD29-50CA-4B2C-4A07-498ADF3AF487",
#           "label": "Il\u0131p\u0131nar Zooarchaeology",
#           "json": "https://opencontext.org/search/.json?q=roman&proj=36-ilipinar-zooarchaeology",
#           "id": "https://opencontext.org/search/?q=roman&proj=36-ilipinar-zooarchaeology"
#         },
#         {
#           "count": 1,
#           "slug": "9-iraq-heritage-program",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/GHF1PRJ0000000025",
#           "label": "Iraq Heritage Program",
#           "json": "https://opencontext.org/search/.json?q=roman&proj=9-iraq-heritage-program",
#           "id": "https://opencontext.org/search/?q=roman&proj=9-iraq-heritage-program"
#         },
#         {
#           "count": 1,
#           "slug": "99-idalion",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/df8e4efd-e06b-4b0b-a056-08b6fd199536",
#           "label": "Idalion",
#           "json": "https://opencontext.org/search/.json?q=roman&proj=99-idalion",
#           "id": "https://opencontext.org/search/?q=roman&proj=99-idalion"
#         }
#       ],
#       "type": "oc-api:facet-project",
#       "id": "#facet-project"
#     },
#     {
#       "rdfs:isDefinedBy": "oc-api:facet-prop-ld",
#       "label": "Descriptions (Common Standards)",
#       "data-type": "id",
#       "oc-api:has-id-options": [
#         {
#           "count": 10539,
#           "slug": "dc-terms-temporal",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/temporal",
#           "label": "Temporal Coverage",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-temporal&q=roman",
#           "id": "https://opencontext.org/search/?prop=dc-terms-temporal&q=roman"
#         },
#         {
#           "count": 5351,
#           "slug": "cidoc-crm-p2-has-type",
#           "rdfs:isDefinedBy": "http://erlangen-crm.org/current/P2_has_type",
#           "label": "Has type",
#           "json": "https://opencontext.org/search/.json?prop=cidoc-crm-p2-has-type&q=roman",
#           "id": "https://opencontext.org/search/?prop=cidoc-crm-p2-has-type&q=roman"
#         },
#         {
#           "count": 4282,
#           "slug": "skos-related",
#           "rdfs:isDefinedBy": "http://www.w3.org/2004/02/skos/core#related",
#           "label": "Related",
#           "json": "https://opencontext.org/search/.json?prop=skos-related&q=roman",
#           "id": "https://opencontext.org/search/?prop=skos-related&q=roman"
#         },
#         {
#           "count": 3184,
#           "slug": "rel--cidoc-crm-p2-has-type",
#           "rdfs:isDefinedBy": "http://erlangen-crm.org/current/P2_has_type",
#           "label": "Has type",
#           "json": "https://opencontext.org/search/.json?prop=rel--cidoc-crm-p2-has-type&q=roman",
#           "id": "https://opencontext.org/search/?prop=rel--cidoc-crm-p2-has-type&q=roman"
#         },
#         {
#           "count": 1089,
#           "slug": "rel--cidoc-crm-p45-consists-of",
#           "rdfs:isDefinedBy": "http://erlangen-crm.org/current/P45_consists_of",
#           "label": "Consists of",
#           "json": "https://opencontext.org/search/.json?prop=rel--cidoc-crm-p45-consists-of&q=roman",
#           "id": "https://opencontext.org/search/?prop=rel--cidoc-crm-p45-consists-of&q=roman"
#         },
#         {
#           "count": 988,
#           "slug": "oc-zoo-has-anat-id",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/open-context-zooarch/has-anat-id",
#           "label": "Has anatomical identification",
#           "json": "https://opencontext.org/search/.json?prop=oc-zoo-has-anat-id&q=roman",
#           "id": "https://opencontext.org/search/?prop=oc-zoo-has-anat-id&q=roman"
#         },
#         {
#           "count": 964,
#           "slug": "biol-term-hastaxonomy",
#           "rdfs:isDefinedBy": "http://purl.org/NET/biol/ns#term_hasTaxonomy",
#           "label": "Has Biological Taxonomy",
#           "json": "https://opencontext.org/search/.json?prop=biol-term-hastaxonomy&q=roman",
#           "id": "https://opencontext.org/search/?prop=biol-term-hastaxonomy&q=roman"
#         },
#         {
#           "count": 542,
#           "slug": "oc-zoo-anatomical-meas",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/open-context-zooarch/anatomical-meas",
#           "label": "Anatomical measurement",
#           "json": "https://opencontext.org/search/.json?prop=oc-zoo-anatomical-meas&q=roman",
#           "id": "https://opencontext.org/search/?prop=oc-zoo-anatomical-meas&q=roman"
#         },
#         {
#           "count": 527,
#           "slug": "dc-terms-references",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/references",
#           "label": "References",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-references&q=roman",
#           "id": "https://opencontext.org/search/?prop=dc-terms-references&q=roman"
#         },
#         {
#           "count": 521,
#           "slug": "oc-zoo-has-fusion-char",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/open-context-zooarch/has-fusion-char",
#           "label": "Has fusion character",
#           "json": "https://opencontext.org/search/.json?prop=oc-zoo-has-fusion-char&q=roman",
#           "id": "https://opencontext.org/search/?prop=oc-zoo-has-fusion-char&q=roman"
#         },
#         {
#           "count": 495,
#           "slug": "cidoc-crm-p45-consists-of",
#           "rdfs:isDefinedBy": "http://erlangen-crm.org/current/P45_consists_of",
#           "label": "Consists of",
#           "json": "https://opencontext.org/search/.json?prop=cidoc-crm-p45-consists-of&q=roman",
#           "id": "https://opencontext.org/search/?prop=cidoc-crm-p45-consists-of&q=roman"
#         },
#         {
#           "count": 491,
#           "slug": "dc-terms-ispartof",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/isPartOf",
#           "label": "Is Part Of",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-ispartof&q=roman",
#           "id": "https://opencontext.org/search/?prop=dc-terms-ispartof&q=roman"
#         },
#         {
#           "count": 420,
#           "slug": "skos-closematch",
#           "rdfs:isDefinedBy": "http://www.w3.org/2004/02/skos/core#closeMatch",
#           "label": "Close Match",
#           "json": "https://opencontext.org/search/.json?prop=skos-closematch&q=roman",
#           "id": "https://opencontext.org/search/?prop=skos-closematch&q=roman"
#         },
#         {
#           "count": 137,
#           "slug": "rel--gawd-origin",
#           "rdfs:isDefinedBy": "http://gawd.atlantides.org/terms/origin",
#           "label": "Origin place",
#           "json": "https://opencontext.org/search/.json?prop=rel--gawd-origin&q=roman",
#           "id": "https://opencontext.org/search/?prop=rel--gawd-origin&q=roman"
#         },
#         {
#           "count": 125,
#           "slug": "rel--dc-terms-subject",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/subject",
#           "label": "Subject",
#           "json": "https://opencontext.org/search/.json?prop=rel--dc-terms-subject&q=roman",
#           "id": "https://opencontext.org/search/?prop=rel--dc-terms-subject&q=roman"
#         },
#         {
#           "count": 70,
#           "slug": "gawd-origin",
#           "rdfs:isDefinedBy": "http://gawd.atlantides.org/terms/origin",
#           "label": "Origin place",
#           "json": "https://opencontext.org/search/.json?prop=gawd-origin&q=roman",
#           "id": "https://opencontext.org/search/?prop=gawd-origin&q=roman"
#         },
#         {
#           "count": 48,
#           "slug": "dc-terms-subject",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/subject",
#           "label": "Subject",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-subject&q=roman",
#           "id": "https://opencontext.org/search/?prop=dc-terms-subject&q=roman"
#         },
#         {
#           "count": 18,
#           "slug": "dc-terms-isreferencedby",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/isReferencedBy",
#           "label": "Is Referenced By",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-isreferencedby&q=roman",
#           "id": "https://opencontext.org/search/?prop=dc-terms-isreferencedby&q=roman"
#         },
#         {
#           "count": 17,
#           "slug": "dc-terms-haspart",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/hasPart",
#           "label": "Has Part",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-haspart&q=roman",
#           "id": "https://opencontext.org/search/?prop=dc-terms-haspart&q=roman"
#         },
#         {
#           "count": 14,
#           "slug": "bibo-status",
#           "rdfs:isDefinedBy": "http://purl.org/ontology/bibo/status",
#           "label": "Status",
#           "json": "https://opencontext.org/search/.json?prop=bibo-status&q=roman",
#           "id": "https://opencontext.org/search/?prop=bibo-status&q=roman"
#         },
#         {
#           "count": 12,
#           "slug": "dc-terms-spatial",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/spatial",
#           "label": "Spatial",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-spatial&q=roman",
#           "id": "https://opencontext.org/search/?prop=dc-terms-spatial&q=roman"
#         },
#         {
#           "count": 11,
#           "slug": "dc-terms-coverage",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/coverage",
#           "label": "Coverage",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-coverage&q=roman",
#           "id": "https://opencontext.org/search/?prop=dc-terms-coverage&q=roman"
#         },
#         {
#           "count": 8,
#           "slug": "oc-zoo-has-phys-sex-det",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/open-context-zooarch/has-phys-sex-det",
#           "label": "Has physiological sex determination",
#           "json": "https://opencontext.org/search/.json?prop=oc-zoo-has-phys-sex-det&q=roman",
#           "id": "https://opencontext.org/search/?prop=oc-zoo-has-phys-sex-det&q=roman"
#         },
#         {
#           "count": 6,
#           "slug": "dinaa-00001",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/dinaa/00001",
#           "label": "Has period",
#           "json": "https://opencontext.org/search/.json?prop=dinaa-00001&q=roman",
#           "id": "https://opencontext.org/search/?prop=dinaa-00001&q=roman"
#         },
#         {
#           "count": 1,
#           "slug": "rel--dc-terms-references",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/references",
#           "label": "References",
#           "json": "https://opencontext.org/search/.json?prop=rel--dc-terms-references&q=roman",
#           "id": "https://opencontext.org/search/?prop=rel--dc-terms-references&q=roman"
#         }
#       ],
#       "oc-api:has-text-options": [
#         {
#           "count": 133,
#           "slug": "rel--skos-altlabel",
#           "rdfs:isDefinedBy": "http://www.w3.org/2004/02/skos/core#altLabel",
#           "label": "Alternative label",
#           "json": "https://opencontext.org/search/.json?prop=rel--skos-altlabel&q=roman",
#           "id": "https://opencontext.org/search/?prop=rel--skos-altlabel&q=roman"
#         },
#         {
#           "count": 6,
#           "slug": "skos-altlabel",
#           "rdfs:isDefinedBy": "http://www.w3.org/2004/02/skos/core#altLabel",
#           "label": "Alternative label",
#           "json": "https://opencontext.org/search/.json?prop=skos-altlabel&q=roman",
#           "id": "https://opencontext.org/search/?prop=skos-altlabel&q=roman"
#         },
#         {
#           "count": 3,
#           "slug": "dc-terms-identifier",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/identifier",
#           "label": "Identifier",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-identifier&q=roman",
#           "id": "https://opencontext.org/search/?prop=dc-terms-identifier&q=roman"
#         }
#       ],
#       "type": "oc-api:facet-prop",
#       "id": "#facet-prop-ld"
#     },
#     {
#       "oc-api:has-rel-media-options": [
#         {
#           "count": 1883,
#           "json": "https://opencontext.org/search/.json?images=1&q=roman",
#           "id": "https://opencontext.org/search/?images=1&q=roman",
#           "label": "Linked with images"
#         },
#         {
#           "count": 41,
#           "json": "https://opencontext.org/search/.json?other-media=1&q=roman",
#           "id": "https://opencontext.org/search/?other-media=1&q=roman",
#           "label": "Linked with media (non-image)"
#         },
#         {
#           "count": 19,
#           "json": "https://opencontext.org/search/.json?q=roman&documents=1",
#           "id": "https://opencontext.org/search/?q=roman&documents=1",
#           "label": "Linked with documents"
#         }
#       ],
#       "id": "#related-media",
#       "label": "Has Related Media"
#     }
#   ],
#   "totalResults": 21565,
#   "last-json": "https://opencontext.org/search/.json?q=roman&start=21560&rows=20",
#   "last": "https://opencontext.org/search/?q=roman&start=21560&rows=20",
#   "oc-api:max-disc-tile-zoom": 20,
#   "oc-api:has-sorting": [
#     {
#       "json": "https://opencontext.org/search/.json?sort=item--asc&q=roman",
#       "oc-api:sort-order": "ascending",
#       "type": "oc-api:sort-item",
#       "id": "https://opencontext.org/search/?sort=item--asc&q=roman",
#       "label": "Item (type, provenance, label)"
#     },
#     {
#       "json": "https://opencontext.org/search/.json?sort=item--desc&q=roman",
#       "oc-api:sort-order": "descending",
#       "type": "oc-api:sort-item",
#       "id": "https://opencontext.org/search/?sort=item--desc&q=roman",
#       "label": "Item (type, provenance, label)"
#     },
#     {
#       "json": "https://opencontext.org/search/.json?sort=updated--asc&q=roman",
#       "oc-api:sort-order": "ascending",
#       "type": "oc-api:sort-updated",
#       "id": "https://opencontext.org/search/?sort=updated--asc&q=roman",
#       "label": "Updated"
#     },
#     {
#       "json": "https://opencontext.org/search/.json?sort=updated--desc&q=roman",
#       "oc-api:sort-order": "descending",
#       "type": "oc-api:sort-updated",
#       "id": "https://opencontext.org/search/?sort=updated--desc&q=roman",
#       "label": "Updated"
#     }
#   ],
#   "oc-api:has-text-search": [
#     {
#       "oc-api:template": "https://opencontext.org/search/?q={SearchTerm}",
#       "oc-api:template-json": "https://opencontext.org/search/.json?q={SearchTerm}",
#       "id": "#textfield-keyword-search",
#       "oc-api:search-term": "roman",
#       "label": "General Keyword Search"
#     }
#   ]
# }

# %%
# dump json to file
import json
with open('romandata.json', 'w') as outfile:
    json.dump(data, outfile)
